# %%
import pandas as pd
import numpy as np

# %%
isp=pd.read_csv("C:/Users/Neeraj Dheeman/Desktop/ideaspiceemployeeturnoverdatset.csv")

# %%
isp.columns
# Out:
# Index(['EmployeId', 'Age', 'Gender', 'MaritalStatus', 'Turnover', 'Travelling',
#        'Vertical', 'Qualifications', 'EducationField', 'EmployeSatisfaction',
#        'JobEngagement', 'JobLevel', 'JobSatisfaction', 'Role', 'DailyBilling',
#        'HourBilling', 'MonthlyBilling', 'MonthlyRate', 'Work Experience',
#        'OverTime', 'PercentSalaryHike', 'Last Rating',
#        'RelationshipSatisfaction', 'Hours', 'StockOptionLevel',
#        'TrainingTimesLastYear', 'Work&Life', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrentManager', 'DistanceFromHome'],
#       dtype='object')

# %%
isp
# Out:
#       EmployeId  Age Gender MaritalStatus Turnover Travelling  \
# 0            63   29      M      Divorced       No  Sometimes
# 1           723   23      M        Single       No     Mostly
# 2          1297   36      M        Single      Yes  Sometimes
# 3            51   30      M      Divorced       No  Sometimes
# 4          1498   29      M        Single      Yes  Sometimes
# ...         ...  ...    ...           ...      ...        ...
# 1465        702   49      M      Divorced       No  Sometimes
# 1466       1999   30      F       Married       No     Mostly
# 1467       1395   21      M        Single       No     Mostly
# 1468        919   42      M       Married       No  Sometimes
# 1469         97   42      M        Single       No     Mostly
#
#                     Vertical  Qualifications    EducationField  \
# 0     Research & Development               1           Medical
# 1                      Sales               1     Life Sciences
# ...

# %%
# checking for null values
isp.isnull().sum()
# Out:
# EmployeId                   0
# Age                         0
# Gender                      0
# MaritalStatus               0
# Turnover                    0
# Travelling                  0
# Vertical                    0
# Qualifications              0
# EducationField              0
# EmployeSatisfaction         0
# JobEngagement               0
# JobLevel                    0
# JobSatisfaction             0
# Role                        0
# DailyBilling                0
# HourBilling                 0
# MonthlyBilling              0
# MonthlyRate                 0
# Work Experience             0
# OverTime                    0
# PercentSalaryHike           0
# Last Rating                 0
# RelationshipSatisfaction    0
# Hours                       0
# StockOptionLevel            0
# TrainingTimesLastYear       0
# Work&Life                   0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrentManager     0
# ...

# %%
# checking for duplicate values
isp.duplicated().sum()
# Out:
# 0

# %%
isp['Turnover'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
ispcopy=isp

# %%
# convert the target variable values to 0 and 1,
ispcopy['Turnover']=ispcopy['Turnover'].str.replace('Yes','1')
ispcopy['Turnover']=ispcopy['Turnover'].str.replace('No','0')

# %%
ispcopy['Turnover']=pd.to_numeric(ispcopy["Turnover"])

# %%
ispcopy['Turnover'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# separate features from target values
ispcopy_x = ispcopy[['EmployeId', 'Age', 'Gender', 'MaritalStatus','Travelling',
       'Vertical', 'Qualifications', 'EducationField', 'EmployeSatisfaction',
       'JobEngagement', 'JobLevel', 'JobSatisfaction', 'Role', 'DailyBilling',
       'HourBilling', 'MonthlyBilling', 'MonthlyRate', 'Work Experience',
       'OverTime', 'PercentSalaryHike', 'Last Rating',
       'RelationshipSatisfaction', 'Hours', 'StockOptionLevel',
       'TrainingTimesLastYear', 'Work&Life', 'YearsAtCompany',
       'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrentManager', 'DistanceFromHome']]
ispcopy_y = ispcopy['Turnover']

# %%
ispcopy_x
# Out:
#       EmployeId  Age Gender MaritalStatus Travelling                Vertical  \
# 0            63   29      M      Divorced  Sometimes  Research & Development
# 1           723   23      M        Single     Mostly                   Sales
# 2          1297   36      M        Single  Sometimes         Human Resources
# 3            51   30      M      Divorced  Sometimes  Research & Development
# 4          1498   29      M        Single  Sometimes                   Sales
# ...         ...  ...    ...           ...        ...                     ...
# 1465        702   49      M      Divorced  Sometimes  Research & Development
# 1466       1999   30      F       Married     Mostly  Research & Development
# 1467       1395   21      M        Single     Mostly  Research & Development
# 1468        919   42      M       Married  Sometimes                   Sales
# 1469         97   42      M        Single     Mostly  Research & Development
#
# ...

# %%
ispcopy_y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Turnover, Length: 1470, dtype: int64

# %%
# separating numerical and categorial data
numeric_data = ispcopy.select_dtypes(include=[np.number])
catagorial_data = ispcopy.select_dtypes(exclude=[np.number])

# %%
catagorial_data
# Out:
#      Gender MaritalStatus Travelling                Vertical  \
# 0         M      Divorced  Sometimes  Research & Development
# 1         M        Single     Mostly                   Sales
# 2         M        Single  Sometimes         Human Resources
# 3         M      Divorced  Sometimes  Research & Development
# 4         M        Single  Sometimes                   Sales
# ...     ...           ...        ...                     ...
# 1465      M      Divorced  Sometimes  Research & Development
# 1466      F       Married     Mostly  Research & Development
# 1467      M        Single     Mostly  Research & Development
# 1468      M       Married  Sometimes                   Sales
# 1469      M        Single     Mostly  Research & Development
#
#         EducationField                    Role OverTime
# 0              Medical   Laboratory Technician       No
# 1        Life Sciences    Sales Representative       No
# 2        Life Sciences                 Manager       No
# ...

# %%
numeric_data
# Out:
#       EmployeId  Age  Turnover  Qualifications  EmployeSatisfaction  \
# 0            63   29         0               1                    3
# 1           723   23         0               1                    2
# 2          1297   36         1               4                    2
# 3            51   30         0               4                    3
# 4          1498   29         1               3                    4
# ...         ...  ...       ...             ...                  ...
# 1465        702   49         0               3                    4
# 1466       1999   30         0               3                    4
# 1467       1395   21         0               1                    4
# 1468        919   42         0               3                    4
# 1469         97   42         0               3                    4
#
#       JobEngagement  JobLevel  JobSatisfaction  DailyBilling  HourBilling  \
# 0                 3         1                1           368           37
# ...

# %%
ispcopy.describe()
# Out:
#          EmployeId          Age     Turnover  Qualifications  \
# count  1470.000000  1470.000000  1470.000000     1470.000000
# mean   1056.771429    37.065306     0.181633        2.876190
# std     594.598084     9.522562     0.385673        1.019038
# min       8.000000    18.000000     0.000000        1.000000
# 25%     531.250000    30.000000     0.000000        2.000000
# 50%    1073.000000    36.000000     0.000000        3.000000
# 75%    1553.750000    44.000000     0.000000        4.000000
# max    2060.000000    59.000000     1.000000        5.000000
#
#        EmployeSatisfaction  JobEngagement     JobLevel  JobSatisfaction  \
# count          1470.000000    1470.000000  1470.000000      1470.000000
# mean              2.702041       2.712245     2.087075         2.785034
# std               1.095039       0.731141     1.109663         1.095840
# min               1.000000       1.000000     1.000000         1.000000
# ...

# %%
ispcopy['EmployeId'].describe()
# Out:
# count    1470.000000
# mean     1056.771429
# std       594.598084
# min         8.000000
# 25%       531.250000
# 50%      1073.000000
# 75%      1553.750000
# max      2060.000000
# Name: EmployeId, dtype: float64

# %%
ispcopy
# Out:
#       EmployeId  Age Gender MaritalStatus  Turnover Travelling  \
# 0            63   29      M      Divorced         0  Sometimes
# 1           723   23      M        Single         0     Mostly
# 2          1297   36      M        Single         1  Sometimes
# 3            51   30      M      Divorced         0  Sometimes
# 4          1498   29      M        Single         1  Sometimes
# ...         ...  ...    ...           ...       ...        ...
# 1465        702   49      M      Divorced         0  Sometimes
# 1466       1999   30      F       Married         0     Mostly
# 1467       1395   21      M        Single         0     Mostly
# 1468        919   42      M       Married         0  Sometimes
# 1469         97   42      M        Single         0     Mostly
#
#                     Vertical  Qualifications    EducationField  \
# 0     Research & Development               1           Medical
# 1                      Sales               1     Life Sciences
# ...
